# %%
from copy import deepcopy
import numpy as np 
import pandas as pd 
from matplotlib import pyplot as plt

# %%
# numeros de clusters
k = 3

n = data.shape[0]
c = data.shape[1]

mean = np.mean(data, axis = 0)
std = np.std(data, axis = 0)
centers = np.random.randn(k,c)*std + mean

# Plot dos centros gerados randomicamente
plt.scatter(data[:,0], data[:,1], s=7)
plt.scatter(centers[:,0], centers[:,1], marker='*', c='g', s=150)

# %%
centers_old = np.zeros(centers.shape) # velhos centros
centers_new = deepcopy(centers) # novos centros

data.shape
clusters = np.zeros(n)
distances = np.zeros((n,k))

error = np.linalg.norm(centers_new - centers_old)

while error != 0:
    # calcula distancia
    for i in range(k):
        distances[:,i] = np.linalg.norm(data - centers[i], axis=1)
    clusters = np.argmin(distances, axis = 1)
    
    centers_old = deepcopy(centers_new)
    # calcula a media para cada cluster e atualiza o centro
    for i in range(k):
        centers_new[i] = np.mean(data[clusters == i], axis=0)
    error = np.linalg.norm(centers_new - centers_old)
centers_new
# Out:
# array([[0.09892406, 1.01897437],
#        [3.66872973, 2.72131658],
#        [7.67341661, 2.26477391]])

# %%
plt.scatter(data[:,0], data[:,1], s=7)
plt.scatter(centers_new[:,0], centers_new[:,1], marker='*', c='g', s=150)
